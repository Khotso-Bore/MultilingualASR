# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from IPython.display import Markdown, display

# %%
# # 1. Define the directory path
# folder_path = Path("../dataset/dsfsi-anv/anv")

# # 2. Get all CSV files in the folder (use rglob("*.csv") to include subfolders)
# csv_files = list(folder_path.glob("*.csv"))

# %%
#df = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
df = pd.read_csv("../dataset/dsfsi-anv/anv/za-african-next-voices-compressed_tsn.csv")

# %%
df.head(5)
# Out:
#   language split                                           audio_id  \
# 0      TSN   dev  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 1      TSN   dev  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 2      TSN   dev  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 3      TSN   dev  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 4      TSN   dev  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
#
#                           recorder_uuid      type          system_file_name  \
# 0  12497dbe-1389-11f0-b3c5-0242ac120004  scripted  recording-1744112231.wav
# 1  12497dbe-1389-11f0-b3c5-0242ac120004  scripted  recording-1744112326.wav
# 2  12497dbe-1389-11f0-b3c5-0242ac120004  scripted  recording-1744112367.wav
# 3  12497dbe-1389-11f0-b3c5-0242ac120004  scripted  recording-1744112443.wav
# 4  12497dbe-1389-11f0-b3c5-0242ac120004  scripted  recording-1744112540.wav
#
#                                            file_name  \
# 0  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 1  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 2  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 3  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
# 4  TSN-12497dbe-1389-11f0-b3c5-0242ac120004-SCR-A...
#
#                                            full_path       domain       topic  \
# 0  audio/TSN/12497dbe-1389-11f0-b3c5-0242ac120004...  Agriculture  Accounting
# 1  audio/TSN/12497dbe-1389-11f0-b3c5-0242ac120004...  Agriculture  Leadership
# 2  audio/TSN/12497dbe-1389-11f0-b3c5-0242ac120004...  Agriculture    Sampling
# 3  audio/TSN/12497dbe-1389-11f0-b3c5-0242ac120004...  Agriculture      Cattle
# 4  audio/TSN/12497dbe-1389-11f0-b3c5-0242ac120004...  Agriculture       Award
#
#    ...   duration size_bytes  \
# 0  ...  10.135792     973114
# 1  ...  14.126896    1356260
# 2  ...   3.969875     381186
# 3  ...   9.836521     944384
# 4  ...  24.443688    2346672
#
#                                 microphone_device_id  \
# 0  e8895ea9240786cacd3f6fe7eab9a09b1385e88b69a5cc...
# 1  e8895ea9240786cacd3f6fe7eab9a09b1385e88b69a5cc...
# 2  e8895ea9240786cacd3f6fe7eab9a09b1385e88b69a5cc...
# 3  e8895ea9240786cacd3f6fe7eab9a09b1385e88b69a5cc...
# 4  e8895ea9240786cacd3f6fe7eab9a09b1385e88b69a5cc...
#
#                                     microphone_label signal_to_noise_ratio  \
# 0  Headset Microphone (Poly Blackwire 3320 Series...                 39.57
# 1  Headset Microphone (Poly Blackwire 3320 Series...                 39.57
# 2  Headset Microphone (Poly Blackwire 3320 Series...                 39.57
# 3  Headset Microphone (Poly Blackwire 3320 Series...                 39.57
# 4  Headset Microphone (Poly Blackwire 3320 Series...                 39.57
#
#                                         document_id  source_document  \
# 0  pula-imvula-7395e48a-15c4-4ea8-802a-40537548300d      Pula_imvula
# 1  pula-imvula-2b93a7eb-8e59-4e53-9fa4-7e837e47a6c5      Pula_imvula
# 2  pula-imvula-1ae64f49-906b-4b83-99ac-d197d0bf92b0      Pula_imvula
# 3  pula-imvula-1a5ea8be-b4b1-406a-99f8-85f1770692a6      Pula_imvula
# 4  pula-imvula-139f1c0d-e4fc-4a94-a451-d6325b838b29      Pula_imvula
#
#   audio_sampling_rate audio_num_samples  audio_num_channels
# 0               48000            486518                   1
# 1               48000            678091                   1
# 2               48000            190554                   1
# 3               48000            472153                   1
# 4               48000           1173297                   1
#
# [5 rows x 22 columns]

# %%
df = df.astype({"language":'category',"split":'category','audio_id':'string','recorder_uuid':'string'},)
df = df.astype({'type':'category','domain':'category','topic':'category',})
df = df.astype({'scenario':'string','transcript':'string','document_id':'string','source_document':'category'})
df = df.astype({'microphone_device_id':'string','microphone_label':'category'})

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94601 entries, 0 to 94600
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   language               94601 non-null  category
#  1   split                  94601 non-null  category
#  2   audio_id               94601 non-null  string
#  3   recorder_uuid          94601 non-null  string
#  4   type                   94601 non-null  category
#  5   system_file_name       94601 non-null  object
#  6   file_name              94601 non-null  object
#  7   full_path              94601 non-null  object
#  8   domain                 94601 non-null  category
#  9   topic                  94601 non-null  category
#  10  scenario               60432 non-null  string
#  11  transcript             94531 non-null  string
#  12  duration               94601 non-null  float64
#  13  size_bytes             94601 non-null  int64
#  14  microphone_device_id   94601 non-null  string
#  15  microphone_label       94601 non-null  category
#  16  signal_to_noise_ratio  94601 non-null  float64
#  17  document_id            53162 non-null  string
#  18  source_document        53162 non-null  category
#  19  audio_sampling_rate    94601 non-null  int64
#  20  audio_num_samples      94601 non-null  int64
#  21  audio_num_channels     94601 non-null  int64
# dtypes: category(7), float64(2), int64(4), object(3), string(6)
# memory usage: 11.6+ MB

# %%
df.isnull().sum()
# Out:
# language                     0
# split                        0
# audio_id                     0
# recorder_uuid                0
# type                         0
# system_file_name             0
# file_name                    0
# full_path                    0
# domain                       0
# topic                        0
# scenario                 34169
# transcript                  70
# duration                     0
# size_bytes                   0
# microphone_device_id         0
# microphone_label             0
# signal_to_noise_ratio        0
# document_id              41439
# source_document          41439
# audio_sampling_rate          0
# audio_num_samples            0
# audio_num_channels           0
# dtype: int64

# %%
#count number of unique recorder_uuid
unique_recorders = df['recorder_uuid'].nunique()
print(f"Number of speakers {unique_recorders}")
# Out:
# Number of speakers 462

# %%
#count number of recordings per recorder_uuid
df['recorder_uuid'].value_counts().head(10)
# Out:
# recorder_uuid
# f2b346d3-8e42-11f0-9db2-0242ac120003    401
# af87d786-7f5e-11f0-8be5-0242ac120002    384
# 1b81246f-8ef8-11f0-9db2-0242ac120003    379
# 468f1d43-8d4b-11f0-aaba-0242ac120005    369
# a34c25e7-78ff-11f0-af81-0242ac120005    364
# f06d5745-84b3-11f0-8d83-0242ac120003    348
# 8e48e3fe-63b3-11f0-ad0e-0242ac120002    341
# 3cc844e1-776a-11f0-b9f2-0242ac120002    337
# 18699911-660e-11f0-8fd5-0242ac120002    330
# 04a3a0ea-1533-11f0-bb20-0242ac120003    330
# Name: count, dtype: Int64

# %%
avg_recordings = df['recorder_uuid'].value_counts().mean()
print(f"Average recordings per recorder: {avg_recordings:.2f}")
# Out:
# Average recordings per recorder: 204.76

# %%
drop_coloumns = ['system_file_name','file_name','full_path']
display(df.drop(columns=drop_coloumns).describe(include='all'))
#drop_coloums = ['langauge','system_file_name','file_name','full_path']
# Out:
#        language  split                                           audio_id  \
# count     94601  94601                                              94601
# unique        1      3                                              94601
# top         TSN  train  TSN-fff685b8-624d-11f0-b722-0242ac120002-UNS-T...
# freq      94601  84383                                                  1
# mean        NaN    NaN                                                NaN
# std         NaN    NaN                                                NaN
# min         NaN    NaN                                                NaN
# 25%         NaN    NaN                                                NaN
# 50%         NaN    NaN                                                NaN
# 75%         NaN    NaN                                                NaN
# max         NaN    NaN                                                NaN
#
#                                recorder_uuid      type   domain  \
# count                                  94601     94601    94601
# unique                                   462         2        8
# top     f2b346d3-8e42-11f0-9db2-0242ac120003  scripted  General
# freq                                     401     53162    43833
# mean                                     NaN       NaN      NaN
# std                                      NaN       NaN      NaN
# min                                      NaN       NaN      NaN
# 25%                                      NaN       NaN      NaN
# 50%                                      NaN       NaN      NaN
# 75%                                      NaN       NaN      NaN
# max                                      NaN       NaN      NaN
#
#                                     topic          scenario  \
# count                               94601             60432
# unique                                509               507
# top     Agricultural products and sectors  Commercial Crops
# freq                                 6233              5829
# mean                                  NaN               NaN
# std                                   NaN               NaN
# min                                   NaN               NaN
# 25%                                   NaN               NaN
# 50%                                   NaN               NaN
# 75%                                   NaN               NaN
# max                                   NaN               NaN
#
#                                                transcript      duration  \
# count                                               94531  94601.000000
# unique                                              50104           NaN
# top     Botshelo jwa diritibatsi ke bo tlisitse mathat...           NaN
# freq                                                  281           NaN
# mean                                                  NaN     18.131643
# std                                                   NaN     14.966598
# min                                                   NaN      2.009958
# 25%                                                   NaN      6.713188
# 50%                                                   NaN     12.594083
# 75%                                                   NaN     24.917982
# max                                                   NaN    125.235604
#
#           size_bytes microphone_device_id microphone_label  \
# count   9.460100e+04                94601            94601
# unique           NaN                  827               89
# top              NaN              default          Default
# freq             NaN                38971            34398
# mean    1.712526e+06                  NaN              NaN
# std     1.423313e+06                  NaN              NaN
# min     5.334400e+04                  NaN              NaN
# 25%     6.362040e+05                  NaN              NaN
# 50%     1.187558e+06                  NaN              NaN
# 75%     2.348520e+06                  NaN              NaN
# max     1.444405e+07                  NaN              NaN
#
#         signal_to_noise_ratio                                 document_id  \
# count            94601.000000                                       53162
# unique                    NaN                                         393
# top                       NaN  wrdnt-24c1f75b-7028-488d-b1c1-594dcd41ecca
# freq                      NaN                                       34169
# mean                41.493473                                         NaN
# std                  9.530972                                         NaN
# min                 30.000000                                         NaN
# 25%                 34.440000                                         NaN
# 50%                 39.490000                                         NaN
# 75%                 45.790000                                         NaN
# max                104.820000                                         NaN
#
#         source_document  audio_sampling_rate  audio_num_samples  \
# count             53162              94601.0       9.460100e+04
# unique                3                  NaN                NaN
# top     African_wordnet                  NaN                NaN
# freq              34169                  NaN                NaN
# mean                NaN              48000.0       8.703586e+05
# std                 NaN                  0.0       7.184390e+05
# min                 NaN              48000.0       9.647800e+04
# 25%                 NaN              48000.0       3.222330e+05
# 50%                 NaN              48000.0       6.045160e+05
# 75%                 NaN              48000.0       1.196111e+06
# max                 NaN              48000.0       6.011309e+06
#
#         audio_num_channels
# count              94601.0
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean                   1.0
# std                    0.0
# min                    1.0
# 25%                    1.0
# 50%                    1.0
# 75%                    1.0
# max                    1.0

# %%
# # Use display() combined with Markdown()
# display(Markdown(f"## Now viewing: **Language**"))

# plt.figure(figsize=(6, 4))
# df['language'].value_counts().plot(kind="bar")
# plt.title(f"Value Counts for Column: language")
# plt.xlabel("Language")
# plt.ylabel("Count")
# plt.show()

# %%
# languages = df['language'].unique()
# languages

# %%
# lang_dict = {
#     "isiNdebele": "NBL",
#     "isiXhosa": "XHO",
#     "isiZulu": "ZUL",
#     "Sesotho": "SOT",
#     "Setswana": "TSN",
#     "Tshivenda": "VEN",
#     "Xitsonga": "TSO",
# }

# lang_dict = {
#     "Setswana": "TSN",
#     "Tshivenda": "VEN",
# }

# %%
display_coloumns = ['split','type','domain', 'source_document']
for col in df[display_coloumns].columns:
    # Use display() combined with Markdown()
    plt.figure(figsize=(6, 4))
    df[col].value_counts().plot(kind="bar")
    plt.title(f"Value Counts for {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

    print(f"Value Counts for Column: {col}")
    print(df[col].value_counts())
# Out:
# Value Counts for Column: split
# split
# train       84383
# dev_test     5269
# dev          4949
# Name: count, dtype: int64
# Value Counts for Column: type
# type
# scripted      53162
# unscripted    41439
# Name: count, dtype: int64
# Value Counts for Column: domain
# domain
# General                43833
# Agriculture            12994
# Health                 12211
# Culture and Society     5411
# Transport               5271
# Sports and Hobbies      5198
# Finance                 4882
# Telecommunication       4801
# Name: count, dtype: int64
# Value Counts for Column: source_document
# source_document
# African_wordnet    34169
# Vukuzenzele        16903
# Pula_imvula         2090
# Name: count, dtype: int64

# %%
display_coloumns = ['size_bytes','signal_to_noise_ratio','audio_num_samples']
for col in df[display_coloumns].columns:

    # Pass the data array/series directly
    plt.hist(df[col], bins=15, color="skyblue", edgecolor="black")

    # Adding labels
    plt.title(f"Distribution of {col}")
    plt.xlabel(f"{col} Group")
    plt.ylabel("Count")

    # Display the plot
    plt.show()

    display(df[col].describe())
# Out:
# count    9.460100e+04
# mean     1.712526e+06
# std      1.423313e+06
# min      5.334400e+04
# 25%      6.362040e+05
# 50%      1.187558e+06
# 75%      2.348520e+06
# max      1.444405e+07
# Name: size_bytes, dtype: float64
# count    94601.000000
# mean        41.493473
# std          9.530972
# min         30.000000
# 25%         34.440000
# 50%         39.490000
# 75%         45.790000
# max        104.820000
# Name: signal_to_noise_ratio, dtype: float64
# count    9.460100e+04
# mean     8.703586e+05
# std      7.184390e+05
# min      9.647800e+04
# 25%      3.222330e+05
# 50%      6.045160e+05
# 75%      1.196111e+06
# max      6.011309e+06
# Name: audio_num_samples, dtype: float64

# %%
df = df
display_coloumns = ['duration']
for col in df[display_coloumns].columns:
    # Pass the data array/series directly
    plt.hist(df[col], bins=15, color="skyblue", edgecolor="black")

    # Adding labels
    plt.title(f"Distribution of {col}")
    plt.xlabel(f"{col} Group")
    plt.ylabel("Count")

    # Display the plot
    plt.show()

    display(df[col].describe())
# Out:
# count    94601.000000
# mean        18.131643
# std         14.966598
# min          2.009958
# 25%          6.713188
# 50%         12.594083
# 75%         24.917982
# max        125.235604
# Name: duration, dtype: float64

# %%
df['duration'].mean()
print(f"Average duration of recordings: {df['duration'].mean():.2f} seconds")
# Out:
# Average duration of recordings: 18.13 seconds

# %%
df['duration'].sum()
print(f"Total duration of recordings: {df['duration'].sum():.2f} seconds")
print(f"Total duration of recordings in hours: {df['duration'].sum() / 3600:.2f} hours")
# Out:
# Total duration of recordings: 1715271.54 seconds
# Total duration of recordings in hours: 476.46 hours

# %% [markdown]
# # Transcript Analysis

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

for category in sorted(df['type'].dropna().unique()):
    subset = df[df['type'] == category][['type', 'transcript']].head(10)
    display(Markdown(f"### Type: {category}"))
    display(subset)
# Out:
# ### Type: scripted
#        type  \
# 0  scripted
# 1  scripted
# 2  scripted
# 3  scripted
# 4  scripted
# 5  scripted
# 6  scripted
# 7  scripted
# 8  scripted
# 9  scripted
#
#                                                                                                                                                                                                                                                                        transcript
# 0                                                                                                            Go duela lekgetho go tlhokiwa ditlhankana tse dingwe morago ga ngwaga ya ditšhelete mme ga di kgonwe go dirisiwa go laola ditšhelete tsa go tsamaisa kgwebo ya gago.
# 1                                                                                                                            Phuthego e ne e beilwe go keteka nako le matsapa a setlhopha se a dirisitseng go tsweletse pele lenaneo la go bona balemirui ba ba ka tlhabololwang.
# 2                                                                                                                                                                                                                                         Riseke ya kwelotlase ya thobo ya dijalo
# 3                                                                                                                                                                              Direšene tse di tswakilweng sekgwebo di siame thata e bile di lekalekana sesaense, fela di a tura.
# 4  Go ne go tshweufatsa pelo go utlwa gore balemirui ba bantsi ba leboga basadi, barwa le barwadi ba bona ba ba ipofileng go ba thusa go aga tsamaiso ya bolemirui ka go ba naya thuso mo masimong, go laola tsa mo ofising le ka go thusa go makheta le go rekisa khumo ya bona.
# 5                                                                                                                                 Fa medi e sa kgone go tsenelela mo mmung kgono ya yone ya go tsaya metsi le kotlo e a foktsega mme go fokotsa bokana ba thobo kwa tshimologong.
# 6                                                                                                                                                                                                                                                 Mildly wet, go le metsi gannye.
# 7                                                                                                                                               Tlhola dikolokote tsa maotwana go tlhomamisa gore di sa le pila morago ga go tsamaya mo nageng mo go leng mesima le matlapa teng.
# 8                                                                                                                                          Lenaneo la tiriso ya monontsha le le tshwanetseng korong kgotsa bali le le farologaneng ka ntlha maemo a naiterojene e e ka lokelwang.
# 9                                                                                                                                             Go botlhokwa go itse gore o tlaa boloka mmidi wa gago jang e bile le fa kae gore go se nne tatlhego kgotsa tshenyego epe ya tlhaka.
# ### Type: unscripted
#           type  \
# 73  unscripted
# 74  unscripted
# 75  unscripted
# 76  unscripted
# 77  unscripted
# 78  unscripted
# 79  unscripted
# 80  unscripted
# 81  unscripted
# 82  unscripted
#
#                                                                                                                                                                                                                                                                                                                                                                                                 transcript
# 73                             Balemirui ba tshwanetse go itse gore pula e na leng, le gore e na [?] mo ngwageng gore ba kgone go rulaganya go jala ka nako e e siametseng. [pause] [um] gape ba tshwanetse go itse gore dijalo di na le mekgwa e e farologaneng ya go gola mo [?] e e rileng jaaka go tlhoka go itse gore dijalo tse di rileng di tlhoka [cs] mocheso [?] kana ga di tlhoke [cs] mocheso.
# 74                                                                                      Mo dipolaseng ke fitlhela mefuta e farologaneng e le mentsi jaaka mmopu, ditamati, [um] merogo, le korong. [pause] nna ke ne ke tla netefatsa gore dijalo tsaka di gola sentle kago lebelela maemo a bosa pele ke jala, le gore ke lebe gore pula e na ga kae mo ngwageng le gore e tlo na ka bontsi bo bo rileng.
# 75  Katiso e nepagetseng ke tshireletso e e tokafaditsweng go latela melawana ya pabalesego le go thusa go fokotsa dikotsi le go netefatsa gore badiriti ba sireletsegile mo tikologong ya bone ya tiro. E nngwe gape e ka ba go latela [um] thulaganyo e nepagetseng go tshwana le gore go thusa go rulaganya ditiragatso tsa pabalesego le go netefatsa gore badiri ba latela melawana e e siameng gape.
# 76                                                                                                                                                                                                                                           Merogo e ke itseng ke mefuta ya teng ke thepe, ke morogo wa lephutsi, le morogo wa [?]. [pause] e e jadiwang ke wa dinawa mme wa thepe o fitlhelwa ko nageng.
# 77                                                                                         Dijo tse di tswang mo diphologolong di botlhokwa mo temothuong ya diphologolo [?] ka go bafa [?] e ba [?] go thusa mo go ntsheng matlalo le go dira temothuo ya diphologolo. [?] go ya pele diphologolo di na le fibre le vitamin tse di thusang mo go tsweletseng ga matlalo le go tokafatsa maemo a temothuo.
# 78                                                                                             Mefuta ya dikgogo e ke itseng ke e mebedi ke [?] le Rhode Island Red. [?] yona e ka ruiwa ya thusa barui ka ntlha ya gore e kgona go beela mae a le [cs] mangata mo ngwageng mme e be e none ka bokete bo bo itseng. Rhode Island yona e na le bokgoni ba go beela mae a [cs] mangata le go nona ka bonako.
# 79                                                                                                                        Temothuo ya mo ditoropong le ditshingwana tse di mo [?] e na le seabe se se botlhokwa mo go netefateng phitlhelelo ya dijo le go maatlafatsa matshelo a baagi ba ba nang le bogolofadi go ba thusa go itirela letseno le go [?] go nna le seabe mo setšhabeng sotlhe mo motseng.
# 80                                                                                                                                                                Merogo e na le seabe se se botlhokwa mo boitekanelong jwa motho le go nneng le dikotla. Di na le di-vitamin, di-mineral, le di-fibre tse di thusang go tokafatsa boitekanelo jwa mmele le go netefatsa tshegetso e e siameng ya dikotla.
# 81                                                                                                                                                                                                                                 Nka boloka [?] tikologong e e nang le [cs] mocheso o o siameng, le o o lekanyeditsweng go netefatsa gore ga a senyege, kgotsa nka naya batho ba ba tlhokang gore ba je.
# 82            Thekenoloji e e jaaka dithulaganyo tse di e dirisang tsa go tlhaba diphologolo e ka fetola tsela e e dirang dilo tsa diphologolo ka go phetolela tsamaiso ya diphologolo go thusa diphologolo go tshela le go iketleletsa [?] mo tikologong ya batho di dule le batho sentle le gore di beiwe mo go dulang diphologolo fela le go netefatsa gore di tshela le go [?] mo tikologong ya batho.

# %%
#count none or empty transcripts
empty_transcripts = df['transcript'].isnull().sum() + (df['transcript'].str.strip() == '').sum()
print(f"Number of empty or null transcripts: {empty_transcripts}")
# Out:
# Number of empty or null transcripts: 70

# %% [markdown]
# ## Word analysis

# %%
df['transcript_word_count'] = df['transcript'].apply(lambda x: len(str(x).split()))
plt.hist(df['transcript_word_count'], bins=20, color="lightgreen", edgecolor="black")
plt.title("Distribution of Transcript Word Counts")
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.show()

# %%
#avereage word count per transcript
average_word_count = df['transcript_word_count'].mean()
print(f"Average word count per transcript: {average_word_count:.2f} words")
# Out:
# Average word count per transcript: 34.71 words

# %%
from collections import Counter
all_words = ' '.join(df['transcript'].dropna()).lower().split()
word_counts = Counter(all_words)
top_words = word_counts.most_common(20)
print(f"total unique words: {len(word_counts)}")
# Out:
# total unique words: 61035

# %%
for i, (word, count) in enumerate(top_words, start=1):
    print(f"{i}. {word}: {count}")
# Out:
# 1. go: 185442
# 2. le: 152376
# 3. e: 118999
# 4. ka: 115634
# 5. ba: 114973
# 6. a: 95082
# 7. o: 93604
# 8. ya: 92593
# 9. di: 73143
# 10. ke: 67081
# 11. gore: 65365
# 12. mo: 60170
# 13. tsa: 42842
# 14. tse: 40248
# 15. ga: 36026
# 16. [?]: 32313
# 17. se: 32294
# 18. wa: 31780
# 19. fa: 28521
# 20. mme: 24355

# %% [markdown]
# ## Character analysis

# %%
df['transcript_char_count'] = df['transcript'].apply(lambda x: len(str(x)))

plt.hist(df['transcript_char_count'], bins=20, color="lightgreen", edgecolor="black")
plt.title(f"Distribution of Transcript Character Counts")
plt.xlabel("Character Count")
plt.ylabel("Frequency")
plt.show()

# %%
#average character count per transcript
average_char_count = df['transcript_char_count'].mean()
print(f"Average character count per transcript: {average_char_count:.2f} characters")
# Out:
# Average character count per transcript: 179.42 characters

# %% [markdown]
# Top characters in transcript

# %%
from collections import Counter
all_chars = ''.join(df['transcript'].dropna()).lower()
filtered_chars = [c for c in all_chars if not c.isspace()]
char_counts = Counter(filtered_chars)
top_chars = char_counts.most_common(20)

number_of_unique_chars = len(char_counts)
print(f" Number of Unique characters: {number_of_unique_chars}")
# Out:
#  Number of Unique characters: 54

# %% [markdown]
# ### Top 20 Characters in Transcript

# %%
for i, (char, count) in enumerate(top_chars, start=1):
    print(f"{i}. {char}: {count}")
# Out:
# 1. a: 2086695
# 2. e: 1653029
# 3. o: 1404180
# 4. t: 906419
# 5. l: 852387
# 6. g: 824430
# 7. n: 749062
# 8. s: 732322
# 9. i: 665027
# 10. k: 555098
# 11. m: 476246
# 12. b: 400332
# 13. h: 338866
# 14. d: 338701
# 15. r: 338322
# 16. w: 266079
# 17. y: 161368
# 18. p: 156674
# 19. .: 132733
# 20. f: 130275
