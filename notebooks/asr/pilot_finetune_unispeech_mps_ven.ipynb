# %% [markdown]
# # Tshivenda UniSpeech Pilot Fine-Tune (M4 / MPS)
#
# Wraps `src/asr/pilot_finetune_unispeech_mps_ven.py` - the seventh ASR model family attempt.
# `microsoft/unispeech-large-1500h-cv`: multi-task phonetically-aware contrastive +
# supervised phonetic CTC pretraining on CommonVoice's multilingual pool, specifically
# validated in its own paper for cross-lingual transfer to unseen languages.
#
# NOT the real Stage 1 run (needs a CUDA GPU) - this is for quick local iteration and
# sanity checks only.
#
# Needs `PYTORCH_ENABLE_MPS_FALLBACK=1` set (CTC loss has no MPS kernel) - set it
# as an environment variable before launching Jupyter, or via the cell below.
#
# **Kernel**: MultilingualASR.

# %%
import os
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

# %% [markdown]
# ## Config

# %%
TRAIN_CLIPS = 5000
EVAL_CLIPS = 500
EPOCHS = 2
BATCH_SIZE = 2
GRAD_ACCUM = 8
LEARNING_RATE = 1e-4
MAX_INPUT_SECONDS = 10.0   # memory cap - see notes/pilot-ven-results.md for why
RESUME_FROM = None          # e.g. "../results/unispeech-ven-pilot/final" to continue
INCLUDE_ANV = False

# %% [markdown]
# ## Run
#
# Slow - for a real overnight run, launch `src/asr/pilot_finetune_unispeech_mps_ven.py` from the terminal in the background instead (see notes/pilot-ven-results.md for the exact commands and heartbeat-monitoring pattern). This cell is for short local test runs.

# %%
import sys, argparse
sys.path.insert(0, "../../src/asr")
import pilot_finetune_unispeech_mps_ven as pft

args = argparse.Namespace(
    train_clips=TRAIN_CLIPS, eval_clips=EVAL_CLIPS, epochs=EPOCHS,
    batch_size=BATCH_SIZE, grad_accum=GRAD_ACCUM, learning_rate=LEARNING_RATE,
    max_input_seconds=MAX_INPUT_SECONDS, resume_from=RESUME_FROM, include_anv=INCLUDE_ANV,
)
pft.main(args)
